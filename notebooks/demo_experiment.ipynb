# %%
import time
from fileman.persistent_print import capture_print, reprint
capture_print(to_file = True)
start_time = time.time()
for i in xrange(20):
    print '%s seconds have passed' % (time.time()-start_time)
    time.sleep(2)
print 'Done!'
